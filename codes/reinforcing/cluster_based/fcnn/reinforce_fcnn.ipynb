# %%
# Forcing me to access all files relative to the main project folder.

import os
os.chdir("/home/srakrn/Works/senior/project/")
os.getcwd()
# Out:
# '/home/srakrn/Works/senior/project'

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as la
import pandas as pd
import torch
import torch.nn.functional as F
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms

# %%
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))]
)

# %%
mnist_trainset = datasets.MNIST(
    root="mnist", train=True, download=True, transform=transform
)
mnist_testset = datasets.MNIST(
    root="mnist", train=False, download=True, transform=transform
)

# %%
trainloader = DataLoader(mnist_trainset, batch_size=64, shuffle=True)
full_trainloader = DataLoader(mnist_trainset, batch_size=len(mnist_trainset), shuffle=True)
testloader = DataLoader(mnist_testset, batch_size=1, shuffle=False)

# %%
class MnistFcnn(nn.Module):
    def __init__(self):
        super(MnistFcnn, self).__init__()
        self.linear1 = nn.Linear(784, 128)
        self.linear2 = nn.Linear(128, 64)
        self.linear3 = nn.Linear(64, 10)

    def forward(self, x):
        x = x.reshape(-1, 28 * 28)
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        x = self.linear3(x)
        return x

# %%
model = MnistFcnn()
mnist_state = torch.load("models/mnist_fcnn.model")
model.load_state_dict(mnist_state)
# Out:
# <All keys matched successfully>

# %%
y_test = []
y_pred = []
for image, label in testloader:
    y_test.append(label.item())
    y_pred.append(model(image).argmax(axis=1).item())

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       980
#            1       0.97      0.97      0.97      1135
#            2       0.93      0.92      0.93      1032
#            3       0.91      0.92      0.91      1010
#            4       0.93      0.93      0.93       982
#            5       0.91      0.89      0.90       892
#            6       0.93      0.95      0.94       958
#            7       0.95      0.91      0.93      1028
#            8       0.89      0.90      0.89       974
#            9       0.92      0.91      0.92      1009
#
#     accuracy                           0.93     10000
#    macro avg       0.93      0.93      0.93     10000
# weighted avg       0.93      0.93      0.93     10000

# %%
trainset_perturbs = torch.load("perturbs/on_single_point/fcnn_trainset_on_single_point.pt")
testset_perturbs = torch.load("perturbs/on_single_point/fcnn_testset_on_single_point.pt")

# %%
y_test = []
y_pred = []
for (image, label), perturb in zip(testloader, trainset_perturbs):
    y_test.append(label.item())
    y_pred.append(model(image + 0.2 * perturb.reshape(1, 1, 28, 28)).argmax(axis=1).item())

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       980
#            1       0.95      0.47      0.63      1135
#            2       0.48      0.83      0.61      1032
#            3       0.51      0.74      0.60      1010
#            4       0.83      0.63      0.72       982
#            5       0.61      0.67      0.64       892
#            6       0.85      0.69      0.76       958
#            7       0.82      0.67      0.74      1028
#            8       0.56      0.66      0.60       974
#            9       0.76      0.53      0.62      1009
#
#     accuracy                           0.68     10000
#    macro avg       0.72      0.68      0.68     10000
# weighted avg       0.73      0.68      0.68     10000

# %%
plt.imshow((image + 0.3 * perturb.reshape(1, 1, 28, 28)).reshape(28, 28).detach().numpy())
plt.show()

# %%
def calculate_k_perturbs(
    model, training_set, clusterer, k, n_epoches=20, verbose=0, log=False
):
    loader = DataLoader(training_set, batch_size=len(training_set), shuffle=False)
    X, y = next(iter(loader))
    km = KMeans(n_clusters=k, verbose=verbose, n_init=3)
    km_clusters = km.fit_predict(clusterer.reshape(len(clusterer), -1))
    print(f"Training {k} perturbs")

    k_points = []
    k_perturbs = []
    losses = []

    for i in set(km_clusters):
        if log:
            log_f = open(log, "a")
        idx = np.where(km_clusters == i)[0]
        data = [training_set[j] for j in idx]
        trainloader = DataLoader(data, batch_size=len(data), shuffle=False)

        perturb = torch.zeros([1, 28 * 28], requires_grad=True)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adagrad([perturb], lr=0.03)

        if verbose:
            print(f"Training #{i+1} perturb")
            print(f"\tThis set of perturbation will attack {len(data)} data points.")

        for e in range(n_epoches):
            running_loss = 0
            for images, labels in trainloader:
                images = images.reshape(-1, 28 * 28)
                optimizer.zero_grad()
                output = model(images + perturb)
                loss = -1 * criterion(output, labels)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                perturb.data.clamp(-1, 1)
        if verbose:
            print(f"\tTraining loss: {-1 * running_loss/len(trainloader)}")
        losses.append(-1 * running_loss / len(trainloader))
        k_points.append(idx)
        k_perturbs.append(perturb.detach().numpy())
    if log:
        t = time.strftime("%H:%M:%S", time.localtime())
        log_f.write(f"{t},{k},")
        log_f.write(",".join([f"{i:.5f}" for i in losses]))
        log_f.write("\n")
    return [k_points, k_perturbs, km]

# %%
train_target, train_perturb, train_km = calculate_k_perturbs(
    model, mnist_trainset, trainset_perturbs.detach().numpy(), 100, verbose=2
)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4406033.5
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4347936.0
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4331541.5
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4325271.0
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4322342.5
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4320520.5
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4319275.0
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4318274.5
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4317538.0
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4317034.5
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4316464.0
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4315482.0
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4314663.5
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 4314052.0
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 4313687.5
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 4313436.0
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 4313278.0
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 4313098.5
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 4312902.5
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 4312728.5
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 4312575.5
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 4312428.0
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 4312305.5
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 4312184.5
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 4312023.0
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 4311893.0
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 4311821.5
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 4311779.0
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 4311750.0
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 4311726.0
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 4311677.0
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 4311645.0
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 4311643.0
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 4311640.0
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 4311635.0
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 4311635.0
# center shift 0.000000e+00 within tolerance 7.956775e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4460929.5
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4412914.0
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4402254.5
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4397742.5
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4394845.5
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4393042.0
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4391657.0
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4390571.0
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4389377.0
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4387805.0
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4384407.5
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4382862.5
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4382564.0
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 4382287.5
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 4382039.0
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 4381759.5
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 4381445.0
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 4381129.0
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 4380725.0
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 4380203.0
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 4379521.5
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 4379073.5
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 4378805.5
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 4378661.0
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 4378595.0
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 4378574.5
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 4378551.0
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 4378537.0
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 4378532.5
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 4378522.5
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 4378516.0
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 4378510.5
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 4378498.5
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 4378486.5
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 4378481.5
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 4378475.0
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 4378467.5
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 4378459.0
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 4378444.5
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 4378444.0
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 4378441.0
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 4378437.0
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 4378434.5
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 4378435.0
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 4378434.0
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 4378431.0
# start iteration
# done sorting
# end inner loop
# Iteration 46, inertia 4378429.5
# start iteration
# done sorting
# end inner loop
# Iteration 47, inertia 4378429.5
# start iteration
# done sorting
# end inner loop
# Iteration 48, inertia 4378425.0
# start iteration
# done sorting
# end inner loop
# Iteration 49, inertia 4378421.5
# start iteration
# done sorting
# end inner loop
# Iteration 50, inertia 4378419.0
# start iteration
# done sorting
# end inner loop
# Iteration 51, inertia 4378417.0
# start iteration
# done sorting
# end inner loop
# Iteration 52, inertia 4378417.0
# center shift 0.000000e+00 within tolerance 7.956775e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4410323.0
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4356619.0
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4343359.5
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4339992.0
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4338367.0
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4336940.5
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4335830.5
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4334751.0
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4332832.0
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4328547.0
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4327493.0
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4327157.5
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4326931.5
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 4326776.0
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 4326677.5
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 4326609.5
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 4326581.5
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 4326564.0
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 4326555.0
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 4326552.5
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 4326547.0
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 4326550.0
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 4326548.0
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 4326548.0
# center shift 0.000000e+00 within tolerance 7.956775e-05
# Training 100 perturbs
# Training #1 perturb
# 	This set of perturbation will attack 804 data points.
# 	Training loss: 13.61217975616455
# Training #2 perturb
# 	This set of perturbation will attack 2178 data points.
# 	Training loss: 12.957147598266602
# Training #3 perturb
# 	This set of perturbation will attack 1764 data points.
# 	Training loss: 7.527134418487549
# Training #4 perturb
# 	This set of perturbation will attack 802 data points.
# 	Training loss: 7.310203552246094
# Training #5 perturb
# 	This set of perturbation will attack 1193 data points.
# 	Training loss: 13.582525253295898
# Training #6 perturb
# 	This set of perturbation will attack 1213 data points.
# 	Training loss: 10.994975090026855
# Training #7 perturb
# 	This set of perturbation will attack 1135 data points.
# 	Training loss: 16.592573165893555
# Training #8 perturb
# 	This set of perturbation will attack 1794 data points.
# 	Training loss: 5.984939098358154
# Training #9 perturb
# 	This set of perturbation will attack 306 data points.
# 	Training loss: 9.210210800170898
# Training #10 perturb
# 	This set of perturbation will attack 665 data points.
# 	Training loss: 11.87166976928711
# Training #11 perturb
# 	This set of perturbation will attack 734 data points.
# 	Training loss: 8.674897193908691
# Training #12 perturb
# 	This set of perturbation will attack 706 data points.
# 	Training loss: 11.733245849609375
# Training #13 perturb
# 	This set of perturbation will attack 1805 data points.
# 	Training loss: 12.34312629699707
# Training #14 perturb
# 	This set of perturbation will attack 1047 data points.
# 	Training loss: 10.907115936279297
# Training #15 perturb
# 	This set of perturbation will attack 397 data points.
# 	Training loss: 6.971560478210449
# Training #16 perturb
# 	This set of perturbation will attack 1192 data points.
# 	Training loss: 7.084343910217285
# Training #17 perturb
# 	This set of perturbation will attack 534 data points.
# 	Training loss: 10.116636276245117
# Training #18 perturb
# 	This set of perturbation will attack 601 data points.
# 	Training loss: 11.734169006347656
# Training #19 perturb
# 	This set of perturbation will attack 504 data points.
# 	Training loss: 8.550939559936523
# Training #20 perturb
# 	This set of perturbation will attack 396 data points.
# 	Training loss: 14.089423179626465
# Training #21 perturb
# 	This set of perturbation will attack 574 data points.
# 	Training loss: 9.538418769836426
# Training #22 perturb
# 	This set of perturbation will attack 786 data points.
# 	Training loss: 9.338993072509766
# Training #23 perturb
# 	This set of perturbation will attack 780 data points.
# 	Training loss: 10.28588581085205
# Training #24 perturb
# 	This set of perturbation will attack 907 data points.
# 	Training loss: 12.34875202178955
# Training #25 perturb
# 	This set of perturbation will attack 516 data points.
# 	Training loss: 8.14128303527832
# Training #26 perturb
# 	This set of perturbation will attack 728 data points.
# 	Training loss: 9.81924057006836
# Training #27 perturb
# 	This set of perturbation will attack 769 data points.
# 	Training loss: 7.282731533050537
# Training #28 perturb
# 	This set of perturbation will attack 745 data points.
# 	Training loss: 12.825825691223145
# Training #29 perturb
# 	This set of perturbation will attack 309 data points.
# 	Training loss: 8.889607429504395
# Training #30 perturb
# 	This set of perturbation will attack 745 data points.
# 	Training loss: 12.941783905029297
# Training #31 perturb
# 	This set of perturbation will attack 635 data points.
# 	Training loss: 14.27132797241211
# Training #32 perturb
# 	This set of perturbation will attack 419 data points.
# 	Training loss: 9.604864120483398
# Training #33 perturb
# 	This set of perturbation will attack 1342 data points.
# 	Training loss: 13.417576789855957
# Training #34 perturb
# 	This set of perturbation will attack 136 data points.
# 	Training loss: 10.030688285827637
# Training #35 perturb
# 	This set of perturbation will attack 591 data points.
# 	Training loss: 10.002399444580078
# Training #36 perturb
# 	This set of perturbation will attack 410 data points.
# 	Training loss: 11.724353790283203
# Training #37 perturb
# 	This set of perturbation will attack 461 data points.
# 	Training loss: 8.998160362243652
# Training #38 perturb
# 	This set of perturbation will attack 250 data points.
# 	Training loss: 13.971445083618164
# Training #39 perturb
# 	This set of perturbation will attack 528 data points.
# 	Training loss: 8.67609691619873
# Training #40 perturb
# 	This set of perturbation will attack 239 data points.
# 	Training loss: 13.1824369430542
# Training #41 perturb
# 	This set of perturbation will attack 444 data points.
# 	Training loss: 12.259221076965332
# Training #42 perturb
# 	This set of perturbation will attack 144 data points.
# 	Training loss: 10.667037963867188
# Training #43 perturb
# 	This set of perturbation will attack 738 data points.
# 	Training loss: 5.636746406555176
# Training #44 perturb
# 	This set of perturbation will attack 632 data points.
# 	Training loss: 8.48691463470459
# Training #45 perturb
# 	This set of perturbation will attack 424 data points.
# 	Training loss: 9.360477447509766
# Training #46 perturb
# 	This set of perturbation will attack 212 data points.
# 	Training loss: 13.23917007446289
# Training #47 perturb
# 	This set of perturbation will attack 424 data points.
# 	Training loss: 12.465097427368164
# Training #48 perturb
# 	This set of perturbation will attack 554 data points.
# 	Training loss: 16.21246337890625
# Training #49 perturb
# 	This set of perturbation will attack 357 data points.
# 	Training loss: 9.47618579864502
# Training #50 perturb
# 	This set of perturbation will attack 389 data points.
# 	Training loss: 12.173844337463379
# Training #51 perturb
# 	This set of perturbation will attack 486 data points.
# 	Training loss: 10.205999374389648
# Training #52 perturb
# 	This set of perturbation will attack 367 data points.
# 	Training loss: 11.924423217773438
# Training #53 perturb
# 	This set of perturbation will attack 367 data points.
# 	Training loss: 11.87581729888916
# Training #54 perturb
# 	This set of perturbation will attack 188 data points.
# 	Training loss: 11.71020793914795
# Training #55 perturb
# 	This set of perturbation will attack 396 data points.
# 	Training loss: 7.932187557220459
# Training #56 perturb
# 	This set of perturbation will attack 479 data points.
# 	Training loss: 11.879125595092773
# Training #57 perturb
# 	This set of perturbation will attack 306 data points.
# 	Training loss: 11.192869186401367
# Training #58 perturb
# 	This set of perturbation will attack 186 data points.
# 	Training loss: 8.835291862487793
# Training #59 perturb
# 	This set of perturbation will attack 193 data points.
# 	Training loss: 12.622137069702148
# Training #60 perturb
# 	This set of perturbation will attack 263 data points.
# 	Training loss: 12.451010704040527
# Training #61 perturb
# 	This set of perturbation will attack 211 data points.
# 	Training loss: 8.905052185058594
# Training #62 perturb
# 	This set of perturbation will attack 1009 data points.
# 	Training loss: 12.021474838256836
# Training #63 perturb
# 	This set of perturbation will attack 146 data points.
# 	Training loss: 8.418647766113281
# Training #64 perturb
# 	This set of perturbation will attack 1037 data points.
# 	Training loss: 9.748340606689453
# Training #65 perturb
# 	This set of perturbation will attack 601 data points.
# 	Training loss: 10.729795455932617
# Training #66 perturb
# 	This set of perturbation will attack 58 data points.
# 	Training loss: 6.448934078216553
# Training #67 perturb
# 	This set of perturbation will attack 163 data points.
# 	Training loss: 10.968039512634277
# Training #68 perturb
# 	This set of perturbation will attack 228 data points.
# 	Training loss: 9.591570854187012
# Training #69 perturb
# 	This set of perturbation will attack 270 data points.
# 	Training loss: 9.819205284118652
# Training #70 perturb
# 	This set of perturbation will attack 159 data points.
# 	Training loss: 11.319304466247559
# Training #71 perturb
# 	This set of perturbation will attack 1427 data points.
# 	Training loss: 11.133417129516602
# Training #72 perturb
# 	This set of perturbation will attack 196 data points.
# 	Training loss: 10.727771759033203
# Training #73 perturb
# 	This set of perturbation will attack 351 data points.
# 	Training loss: 12.477163314819336
# Training #74 perturb
# 	This set of perturbation will attack 627 data points.
# 	Training loss: 14.163546562194824
# Training #75 perturb
# 	This set of perturbation will attack 247 data points.
# 	Training loss: 14.601034164428711
# Training #76 perturb
# 	This set of perturbation will attack 247 data points.
# 	Training loss: 12.155169486999512
# Training #77 perturb
# 	This set of perturbation will attack 128 data points.
# 	Training loss: 13.708849906921387
# Training #78 perturb
# 	This set of perturbation will attack 119 data points.
# 	Training loss: 7.047152042388916
# Training #79 perturb
# 	This set of perturbation will attack 397 data points.
# 	Training loss: 12.073348999023438
# Training #80 perturb
# 	This set of perturbation will attack 205 data points.
# 	Training loss: 9.544942855834961
# Training #81 perturb
# 	This set of perturbation will attack 1793 data points.
# 	Training loss: 15.707600593566895
# Training #82 perturb
# 	This set of perturbation will attack 217 data points.
# 	Training loss: 11.274484634399414
# Training #83 perturb
# 	This set of perturbation will attack 59 data points.
# 	Training loss: 10.534147262573242
# Training #84 perturb
# 	This set of perturbation will attack 408 data points.
# 	Training loss: 6.003135681152344
# Training #85 perturb
# 	This set of perturbation will attack 1431 data points.
# 	Training loss: 10.753522872924805
# Training #86 perturb
# 	This set of perturbation will attack 1366 data points.
# 	Training loss: 12.265356063842773
# Training #87 perturb
# 	This set of perturbation will attack 855 data points.
# 	Training loss: 13.133695602416992
# Training #88 perturb
# 	This set of perturbation will attack 1047 data points.
# 	Training loss: 11.491535186767578
# Training #89 perturb
# 	This set of perturbation will attack 672 data points.
# 	Training loss: 8.540846824645996
# Training #90 perturb
# 	This set of perturbation will attack 518 data points.
# 	Training loss: 10.773268699645996
# Training #91 perturb
# 	This set of perturbation will attack 499 data points.
# 	Training loss: 7.322393417358398
# Training #92 perturb
# 	This set of perturbation will attack 329 data points.
# 	Training loss: 5.8322834968566895
# Training #93 perturb
# 	This set of perturbation will attack 213 data points.
# 	Training loss: 10.280858993530273
# Training #94 perturb
# 	This set of perturbation will attack 611 data points.
# 	Training loss: 8.738877296447754
# Training #95 perturb
# 	This set of perturbation will attack 355 data points.
# 	Training loss: 8.37275505065918
# Training #96 perturb
# 	This set of perturbation will attack 120 data points.
# 	Training loss: 8.73195743560791
# Training #97 perturb
# 	This set of perturbation will attack 603 data points.
# 	Training loss: 11.951358795166016
# Training #98 perturb
# 	This set of perturbation will attack 554 data points.
# 	Training loss: 9.469414710998535
# Training #99 perturb
# 	This set of perturbation will attack 457 data points.
# 	Training loss: 10.19345474243164
# Training #100 perturb
# 	This set of perturbation will attack 878 data points.
# 	Training loss: 6.21591854095459

# %%
test_target, test_perturb, test_km = calculate_k_perturbs(
    model, mnist_testset, testset_perturbs.detach().numpy(), 100, verbose=2
)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 267798.94
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 256381.22
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 254762.98
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 253741.02
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 253248.75
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 252976.52
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 252845.53
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 252749.81
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 252721.19
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 252709.44
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 252702.44
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 252700.11
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 252700.11
# center shift 0.000000e+00 within tolerance 5.840119e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 269290.25
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 261557.56
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 258521.22
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 257532.58
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 256956.95
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 256531.53
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 256245.23
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 256012.11
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 255892.55
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 255815.4
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 255800.42
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 255785.17
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 255754.53
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 255705.31
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 255690.73
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 255688.16
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 255685.62
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 255685.62
# center shift 0.000000e+00 within tolerance 5.840119e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 266833.06
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 259530.39
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 256584.11
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 255993.6
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 255664.67
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 255383.72
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 255246.89
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 255148.77
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 255101.72
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 255056.2
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 254992.95
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 254931.11
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 254861.05
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 254828.66
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 254796.61
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 254763.27
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 254723.88
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 254696.27
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 254580.23
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 254537.75
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 254537.14
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 254537.14
# center shift 0.000000e+00 within tolerance 5.840119e-05
# Training 100 perturbs
# Training #1 perturb
# 	This set of perturbation will attack 194 data points.
# 	Training loss: 9.406865119934082
# Training #2 perturb
# 	This set of perturbation will attack 1567 data points.
# 	Training loss: 3.906543016433716
# Training #3 perturb
# 	This set of perturbation will attack 62 data points.
# 	Training loss: 11.883066177368164
# Training #4 perturb
# 	This set of perturbation will attack 236 data points.
# 	Training loss: 13.156895637512207
# Training #5 perturb
# 	This set of perturbation will attack 205 data points.
# 	Training loss: 13.954239845275879
# Training #6 perturb
# 	This set of perturbation will attack 295 data points.
# 	Training loss: 16.47178840637207
# Training #7 perturb
# 	This set of perturbation will attack 100 data points.
# 	Training loss: 14.000924110412598
# Training #8 perturb
# 	This set of perturbation will attack 197 data points.
# 	Training loss: 12.872733116149902
# Training #9 perturb
# 	This set of perturbation will attack 123 data points.
# 	Training loss: 9.0232572555542
# Training #10 perturb
# 	This set of perturbation will attack 75 data points.
# 	Training loss: 9.593332290649414
# Training #11 perturb
# 	This set of perturbation will attack 101 data points.
# 	Training loss: 14.967796325683594
# Training #12 perturb
# 	This set of perturbation will attack 141 data points.
# 	Training loss: 10.774516105651855
# Training #13 perturb
# 	This set of perturbation will attack 221 data points.
# 	Training loss: 10.996416091918945
# Training #14 perturb
# 	This set of perturbation will attack 62 data points.
# 	Training loss: 10.856728553771973
# Training #15 perturb
# 	This set of perturbation will attack 65 data points.
# 	Training loss: 10.203168869018555
# Training #16 perturb
# 	This set of perturbation will attack 79 data points.
# 	Training loss: 7.473292827606201
# Training #17 perturb
# 	This set of perturbation will attack 192 data points.
# 	Training loss: 6.892053127288818
# Training #18 perturb
# 	This set of perturbation will attack 116 data points.
# 	Training loss: 13.677206993103027
# Training #19 perturb
# 	This set of perturbation will attack 105 data points.
# 	Training loss: 9.937376976013184
# Training #20 perturb
# 	This set of perturbation will attack 175 data points.
# 	Training loss: 9.790252685546875
# Training #21 perturb
# 	This set of perturbation will attack 125 data points.
# 	Training loss: 10.665836334228516
# Training #22 perturb
# 	This set of perturbation will attack 103 data points.
# 	Training loss: 9.364039421081543
# Training #23 perturb
# 	This set of perturbation will attack 66 data points.
# 	Training loss: 12.508757591247559
# Training #24 perturb
# 	This set of perturbation will attack 44 data points.
# 	Training loss: 13.473071098327637
# Training #25 perturb
# 	This set of perturbation will attack 101 data points.
# 	Training loss: 8.764391899108887
# Training #26 perturb
# 	This set of perturbation will attack 43 data points.
# 	Training loss: 12.189105033874512
# Training #27 perturb
# 	This set of perturbation will attack 84 data points.
# 	Training loss: 6.828179359436035
# Training #28 perturb
# 	This set of perturbation will attack 190 data points.
# 	Training loss: 11.76821517944336
# Training #29 perturb
# 	This set of perturbation will attack 87 data points.
# 	Training loss: 9.676583290100098
# Training #30 perturb
# 	This set of perturbation will attack 91 data points.
# 	Training loss: 8.498011589050293
# Training #31 perturb
# 	This set of perturbation will attack 82 data points.
# 	Training loss: 14.40633487701416
# Training #32 perturb
# 	This set of perturbation will attack 182 data points.
# 	Training loss: 13.434276580810547
# Training #33 perturb
# 	This set of perturbation will attack 44 data points.
# 	Training loss: 8.936262130737305
# Training #34 perturb
# 	This set of perturbation will attack 59 data points.
# 	Training loss: 12.12130069732666
# Training #35 perturb
# 	This set of perturbation will attack 19 data points.
# 	Training loss: 5.432561874389648
# Training #36 perturb
# 	This set of perturbation will attack 130 data points.
# 	Training loss: 7.64003324508667
# Training #37 perturb
# 	This set of perturbation will attack 130 data points.
# 	Training loss: 12.565226554870605
# Training #38 perturb
# 	This set of perturbation will attack 46 data points.
# 	Training loss: 11.82180404663086
# Training #39 perturb
# 	This set of perturbation will attack 40 data points.
# 	Training loss: 9.36093521118164
# Training #40 perturb
# 	This set of perturbation will attack 64 data points.
# 	Training loss: 10.276178359985352
# Training #41 perturb
# 	This set of perturbation will attack 65 data points.
# 	Training loss: 8.356453895568848
# Training #42 perturb
# 	This set of perturbation will attack 38 data points.
# 	Training loss: 11.292190551757812
# Training #43 perturb
# 	This set of perturbation will attack 55 data points.
# 	Training loss: 10.83713150024414
# Training #44 perturb
# 	This set of perturbation will attack 63 data points.
# 	Training loss: 12.086762428283691
# Training #45 perturb
# 	This set of perturbation will attack 57 data points.
# 	Training loss: 10.285807609558105
# Training #46 perturb
# 	This set of perturbation will attack 41 data points.
# 	Training loss: 9.548905372619629
# Training #47 perturb
# 	This set of perturbation will attack 104 data points.
# 	Training loss: 8.167983055114746
# Training #48 perturb
# 	This set of perturbation will attack 36 data points.
# 	Training loss: 12.823017120361328
# Training #49 perturb
# 	This set of perturbation will attack 81 data points.
# 	Training loss: 16.40699005126953
# Training #50 perturb
# 	This set of perturbation will attack 30 data points.
# 	Training loss: 9.08096694946289
# Training #51 perturb
# 	This set of perturbation will attack 38 data points.
# 	Training loss: 10.637669563293457
# Training #52 perturb
# 	This set of perturbation will attack 38 data points.
# 	Training loss: 7.764552116394043
# Training #53 perturb
# 	This set of perturbation will attack 25 data points.
# 	Training loss: 11.60042953491211
# Training #54 perturb
# 	This set of perturbation will attack 86 data points.
# 	Training loss: 13.206744194030762
# Training #55 perturb
# 	This set of perturbation will attack 47 data points.
# 	Training loss: 13.194270133972168
# Training #56 perturb
# 	This set of perturbation will attack 54 data points.
# 	Training loss: 12.101000785827637
# Training #57 perturb
# 	This set of perturbation will attack 25 data points.
# 	Training loss: 8.207511901855469
# Training #58 perturb
# 	This set of perturbation will attack 10 data points.
# 	Training loss: 12.896441459655762
# Training #59 perturb
# 	This set of perturbation will attack 93 data points.
# 	Training loss: 12.951597213745117
# Training #60 perturb
# 	This set of perturbation will attack 28 data points.
# 	Training loss: 9.974108695983887
# Training #61 perturb
# 	This set of perturbation will attack 26 data points.
# 	Training loss: 13.535867691040039
# Training #62 perturb
# 	This set of perturbation will attack 50 data points.
# 	Training loss: 10.893998146057129
# Training #63 perturb
# 	This set of perturbation will attack 15 data points.
# 	Training loss: 12.181078910827637
# Training #64 perturb
# 	This set of perturbation will attack 44 data points.
# 	Training loss: 12.610367774963379
# Training #65 perturb
# 	This set of perturbation will attack 23 data points.
# 	Training loss: 7.621734142303467
# Training #66 perturb
# 	This set of perturbation will attack 35 data points.
# 	Training loss: 10.584110260009766
# Training #67 perturb
# 	This set of perturbation will attack 30 data points.
# 	Training loss: 9.241155624389648
# Training #68 perturb
# 	This set of perturbation will attack 32 data points.
# 	Training loss: 10.273223876953125
# Training #69 perturb
# 	This set of perturbation will attack 15 data points.
# 	Training loss: 15.201116561889648
# Training #70 perturb
# 	This set of perturbation will attack 15 data points.
# 	Training loss: 12.736286163330078
# Training #71 perturb
# 	This set of perturbation will attack 39 data points.
# 	Training loss: 10.317423820495605
# Training #72 perturb
# 	This set of perturbation will attack 38 data points.
# 	Training loss: 16.175159454345703
# Training #73 perturb
# 	This set of perturbation will attack 234 data points.
# 	Training loss: 13.677546501159668
# Training #74 perturb
# 	This set of perturbation will attack 306 data points.
# 	Training loss: 11.951765060424805
# Training #75 perturb
# 	This set of perturbation will attack 105 data points.
# 	Training loss: 11.0404691696167
# Training #76 perturb
# 	This set of perturbation will attack 75 data points.
# 	Training loss: 11.795273780822754
# Training #77 perturb
# 	This set of perturbation will attack 183 data points.
# 	Training loss: 12.194242477416992
# Training #78 perturb
# 	This set of perturbation will attack 43 data points.
# 	Training loss: 14.017807006835938
# Training #79 perturb
# 	This set of perturbation will attack 40 data points.
# 	Training loss: 11.985958099365234
# Training #80 perturb
# 	This set of perturbation will attack 18 data points.
# 	Training loss: 13.482268333435059
# Training #81 perturb
# 	This set of perturbation will attack 226 data points.
# 	Training loss: 11.260069847106934
# Training #82 perturb
# 	This set of perturbation will attack 38 data points.
# 	Training loss: 11.550848007202148
# Training #83 perturb
# 	This set of perturbation will attack 86 data points.
# 	Training loss: 7.559147834777832
# Training #84 perturb
# 	This set of perturbation will attack 12 data points.
# 	Training loss: 10.840174674987793
# Training #85 perturb
# 	This set of perturbation will attack 248 data points.
# 	Training loss: 9.794536590576172
# Training #86 perturb
# 	This set of perturbation will attack 52 data points.
# 	Training loss: 11.765252113342285
# Training #87 perturb
# 	This set of perturbation will attack 72 data points.
# 	Training loss: 6.9253668785095215
# Training #88 perturb
# 	This set of perturbation will attack 106 data points.
# 	Training loss: 11.104120254516602
# Training #89 perturb
# 	This set of perturbation will attack 99 data points.
# 	Training loss: 8.58176040649414
# Training #90 perturb
# 	This set of perturbation will attack 197 data points.
# 	Training loss: 7.564304351806641
# Training #91 perturb
# 	This set of perturbation will attack 6 data points.
# 	Training loss: 8.484601020812988
# Training #92 perturb
# 	This set of perturbation will attack 10 data points.
# 	Training loss: 10.239354133605957
# Training #93 perturb
# 	This set of perturbation will attack 79 data points.
# 	Training loss: 10.865710258483887
# Training #94 perturb
# 	This set of perturbation will attack 35 data points.
# 	Training loss: 13.357458114624023
# Training #95 perturb
# 	This set of perturbation will attack 28 data points.
# 	Training loss: 8.004762649536133
# Training #96 perturb
# 	This set of perturbation will attack 33 data points.
# 	Training loss: 6.24605131149292
# Training #97 perturb
# 	This set of perturbation will attack 52 data points.
# 	Training loss: 10.10564136505127
# Training #98 perturb
# 	This set of perturbation will attack 106 data points.
# 	Training loss: 13.529850959777832
# Training #99 perturb
# 	This set of perturbation will attack 28 data points.
# 	Training loss: 9.417037963867188
# Training #100 perturb
# 	This set of perturbation will attack 66 data points.
# 	Training loss: 11.731663703918457

# %%
fig, axs = plt.subplots(10, 10, figsize=(10, 10))
for ax, perturb in zip(axs.ravel(), train_perturb):
    ax.imshow(perturb.reshape(28, 28))
plt.show()

# %%
fig, axs = plt.subplots(10, 10, figsize=(10, 10))
for ax, perturb in zip(axs.ravel(), test_perturb):
    ax.imshow(perturb.reshape(28, 28))
plt.show()

# %%
def get_nth_perturb(n, targets, perturbs):
    for i, j in zip(targets, perturbs):
        if i in targets:
            return j
    return None

# %%
y_test = []
y_pred = []
for i, (image, label) in enumerate(testloader):
    y_test.append(label.item())
    perturb = torch.tensor(get_nth_perturb(i, test_target, test_perturb))
    y_pred.append(model(image + 0.2 * perturb.reshape(1, 1, 28, 28)).argmax(axis=1).item())

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       980
#            1       0.93      0.98      0.95      1135
#            2       0.67      0.96      0.79      1032
#            3       0.55      0.96      0.69      1010
#            4       0.97      0.79      0.87       982
#            5       0.97      0.49      0.65       892
#            6       0.96      0.88      0.92       958
#            7       0.74      0.94      0.83      1028
#            8       0.97      0.46      0.62       974
#            9       0.94      0.62      0.75      1009
#
#     accuracy                           0.81     10000
#    macro avg       0.86      0.80      0.80     10000
# weighted avg       0.86      0.81      0.81     10000

# %%
class PerturbDataset(Dataset):
    def __init__(self, data, targets, perturbs, density = 0.2):
        super().__init__()
        self.data = data
        self.targets = targets
        self.perturbs = perturbs
        self.density = density
    def __len__(self):
        return len(self.data)
    def _get_nth_perturb(self, n):
        for i, j in zip(self.targets, self.perturbs):
            if i in self.targets:
                return j
        return None
    def __getitem__(self, idx):
        X, y  = self.data[idx]
        X += 0.2 * perturb.reshape(1, 28, 28)
        return X, y

# %%
pd = PerturbDataset(mnist_trainset, train_target, train_perturb)

# %%
perturbloader = DataLoader(pd, batch_size=16, shuffle=True)

# %%
criterion = nn.CrossEntropyLoss(reduction='none')
optimizer = optim.Adam(model.parameters())
epochs = 10
for e in range(epochs):
    running_loss = 0
    for (images, labels), (adver_images, adver_labels) in zip(trainloader, perturbloader):
        X = torch.cat([images, adver_images], 0)
        y = torch.cat([labels, adver_labels], 0)
        w = torch.tensor([1 if i < len(labels) else 2 for i in range(len(labels) + len(adver_labels))]).float()
        optimizer.zero_grad()

        output = F.log_softmax(model(X), dim=1)
        loss = torch.dot(criterion(output, y), w)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    else:
        print(f"Training loss: {running_loss/len(trainloader)}")
# Out:
# Training loss: 21.95227226570471
# Training loss: 12.573753699819163
# Training loss: 10.035969775432209
# Training loss: 7.660819547199237
# Training loss: 6.6649539424920645
# Training loss: 6.151157568353834
# Training loss: 5.67292042673905
# Training loss: 5.1222133751807695
# Training loss: 4.516937492403394
# Training loss: 4.334715902090454

# %%
y_test = []
y_pred = []
for image, label in testloader:
    y_test.append(label.item())
    y_pred.append(model(image).argmax(axis=1).item())

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.97      0.99      0.98      1032
#            3       0.97      0.97      0.97      1010
#            4       0.98      0.98      0.98       982
#            5       0.97      0.98      0.97       892
#            6       0.97      0.99      0.98       958
#            7       0.98      0.98      0.98      1028
#            8       0.99      0.96      0.97       974
#            9       0.98      0.96      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
y_test = []
y_pred = []
for (image, label), perturb in zip(testloader, trainset_perturbs):
    y_test.append(label.item())
    y_pred.append(model(image + 0.2 * perturb.reshape(1, 1, 28, 28)).argmax(axis=1).item())

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       980
#            1       0.99      0.86      0.92      1135
#            2       0.83      0.97      0.90      1032
#            3       0.91      0.92      0.91      1010
#            4       0.94      0.93      0.93       982
#            5       0.90      0.96      0.93       892
#            6       0.89      0.97      0.93       958
#            7       0.96      0.86      0.91      1028
#            8       0.82      0.89      0.86       974
#            9       0.94      0.80      0.86      1009
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.92      0.91      0.91     10000

# %%
rem = MnistFcnn()

# %%
criterion = nn.CrossEntropyLoss(reduction='none')
optimizer = optim.Adam(rem.parameters())
epochs = 10
for e in range(epochs):
    running_loss = 0
    for (images, labels), (adver_images, adver_labels) in zip(trainloader, perturbloader):
        X = torch.cat([images, adver_images], 0)
        y = torch.cat([labels, adver_labels], 0)
        w = torch.tensor([1 if i < len(labels) else 2 for i in range(len(labels) + len(adver_labels))]).float()
        optimizer.zero_grad()

        output = F.log_softmax(rem(X), dim=1)
        loss = torch.dot(criterion(output, y), w)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    else:
        print(f"Training loss: {running_loss/len(trainloader)}")
# Out:
# Training loss: 36.7224055922616
# Training loss: 17.125758046026167
# Training loss: 12.336657520169133
# Training loss: 9.651855384108863
# Training loss: 8.081359548037494
# Training loss: 7.131657051442783
# Training loss: 5.983942917256213
# Training loss: 5.576184453438721
# Training loss: 4.932161580064276
# Training loss: 4.71790798427835

# %%
y_test = []
y_pred = []
for image, label in testloader:
    y_test.append(label.item())
    y_pred.append(model(image).argmax(axis=1).item())

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.97      0.99      0.98      1032
#            3       0.97      0.97      0.97      1010
#            4       0.98      0.98      0.98       982
#            5       0.97      0.98      0.97       892
#            6       0.97      0.99      0.98       958
#            7       0.98      0.98      0.98      1028
#            8       0.99      0.96      0.97       974
#            9       0.98      0.96      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
y_test = []
y_pred = []
for (image, label), perturb in zip(testloader, trainset_perturbs):
    y_test.append(label.item())
    y_pred.append(model(image + 0.2 * perturb.reshape(1, 1, 28, 28)).argmax(axis=1).item())

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       980
#            1       0.99      0.86      0.92      1135
#            2       0.83      0.97      0.90      1032
#            3       0.91      0.92      0.91      1010
#            4       0.94      0.93      0.93       982
#            5       0.90      0.96      0.93       892
#            6       0.89      0.97      0.93       958
#            7       0.96      0.86      0.91      1028
#            8       0.82      0.89      0.86       974
#            9       0.94      0.80      0.86      1009
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.92      0.91      0.91     10000
